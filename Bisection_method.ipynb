# %%
import math as m
import pandas as pd

# %%
a = float(input("a:"))
b = float(input("b:"))
error_bound = float(input("Error bound:"))
# Out:
# a:1
# b:2
# Error bound:0.001

# %%
def f(x):
    return x**6 - x - 1

# %%
def bm_approx(a, b, e):
    iter_bound = m.log((b-a)/e) / m.log(2)
    iter= 0
    data= []
    while iter < iter_bound:
        iter += 1
        c = (a+b)/2
        data.append([iter, a, b, c, b-c, f(c)])

        if b-c < e:
            break
        elif b-c > e:
            if m.copysign(1,f(b)) * m.copysign(1,f(c)) == -1:
                a = c
            elif m.copysign(1,f(a)) * m.copysign(1,f(c)) == -1:
                b = c
    return pd.DataFrame(data)

# %%
df = bm_approx(a, b, error_bound)
df.rename(columns={0: "Iteration", 1: "a", 2: "b", 3: "c", 4: "b-c", 5: "f(c)"}, inplace=True)
df.set_index("Iteration", inplace= True)
df.head(15)
# Out:
#                   a         b         c       b-c      f(c)
# Iteration
# 1          1.000000  2.000000  1.500000  0.500000  8.890625
# 2          1.000000  1.500000  1.250000  0.250000  1.564697
# 3          1.000000  1.250000  1.125000  0.125000 -0.097713
# 4          1.125000  1.250000  1.187500  0.062500  0.616653
# 5          1.125000  1.187500  1.156250  0.031250  0.233269
# 6          1.125000  1.156250  1.140625  0.015625  0.061578
# 7          1.125000  1.140625  1.132812  0.007812 -0.019576
# 8          1.132812  1.140625  1.136719  0.003906  0.020619
# 9          1.132812  1.136719  1.134766  0.001953  0.000427
# 10         1.132812  1.134766  1.133789  0.000977 -0.009598
